# %%
import pandas as pd

# %%
excel = '/Users/Ketki/Documents/MS Theses/Reference Papers and Data/Outputs/commonwords_jd_china.docx.xlsx'

# %%
df = pd.DataFrame()
for i in [0,1,2,3,4,6,7,8]:
    malay = pd.read_excel(excel, sheet_name = i)
    malay = malay[['word','Product']]
    malay = malay.set_index('word')
    df = pd.concat([df,malay],axis=1)
df
# Out:
# /Users/Ketki/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#              Product   Product   Product   Product   Product   Product  \
# ability     0.003778  0.003398  0.002052  0.007421       NaN       NaN
# accounting  0.006985  0.008076  0.016258  0.019601  0.007209  0.008694
# actively         NaN       NaN  0.003516       NaN       NaN       NaN
# activities  0.000914  0.000274  0.000497       NaN  0.000734  0.001328
# advanced         NaN  0.000600       NaN       NaN       NaN  0.004360
# ...              ...       ...       ...       ...       ...       ...
# various     0.000433  0.001556  0.000352       NaN  0.000521  0.001413
# ...

# %%
df = df.sum(axis = 1)
df
# Out:
# ability       0.016649
# accounting    0.083724
# actively      0.003516
# activities    0.004299
# advanced      0.004960
#                 ...
# various       0.004667
# work          0.007735
# working       0.010920
# written       0.006719
# years         0.001466
# Length: 149, dtype: float64

# %%
idf = pd.DataFrame()
for i in [5,9]:
    ind = pd.read_excel(excel, sheet_name = i)
    ind = ind[['word','Product']]
    ind = ind.set_index('word')
    idf = pd.concat([idf,ind],axis=1)
idf
# Out:
# /Users/Ketki/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#                Product   Product
# ability       0.001498  0.001252
# accounting    0.003561  0.031732
# activities    0.000725       NaN
# analytical    0.000542  0.000452
# applications       NaN  0.000663
# ...                ...       ...
# types              NaN  0.001072
# various       0.002058  0.000430
# work          0.000370  0.000619
# working       0.000506  0.000846
# years         0.001444  0.000241
#
# [94 rows x 2 columns]

# %%
idf = idf.sum(axis = 1)
idf
# Out:
# ability         0.002750
# accounting      0.035294
# activities      0.000725
# analytical      0.000994
# applications    0.000663
#                   ...
# types           0.001072
# various         0.002488
# work            0.000989
# working         0.001352
# years           0.001686
# Length: 94, dtype: float64

# %%
df = df.reset_index()
idf = idf.reset_index()

# %%
df['nationality']='malaysia'
df = df.rename(columns={'index':'word',0:'freq'})
df
# Out:
#            word      freq nationality
# 0       ability  0.016649    malaysia
# 1    accounting  0.083724    malaysia
# 2      actively  0.003516    malaysia
# 3    activities  0.004299    malaysia
# 4      advanced  0.004960    malaysia
# ..          ...       ...         ...
# 144     various  0.004667    malaysia
# 145        work  0.007735    malaysia
# 146     working  0.010920    malaysia
# 147     written  0.006719    malaysia
# 148       years  0.001466    malaysia
#
# [149 rows x 3 columns]

# %%
idf['nationality']='india'
idf = idf.rename(columns={'index':'word',0:'freq'})
idf
# Out:
#             word      freq nationality
# 0        ability  0.002750       india
# 1     accounting  0.035294       india
# 2     activities  0.000725       india
# 3     analytical  0.000994       india
# 4   applications  0.000663       india
# ..           ...       ...         ...
# 89         types  0.001072       india
# 90       various  0.002488       india
# 91          work  0.000989       india
# 92       working  0.001352       india
# 93         years  0.001686       india
#
# [94 rows x 3 columns]

# %%
df_new = df.append(idf)
df_new
# Out:
#           word      freq nationality
# 0      ability  0.016649    malaysia
# 1   accounting  0.083724    malaysia
# 2     actively  0.003516    malaysia
# 3   activities  0.004299    malaysia
# 4     advanced  0.004960    malaysia
# ..         ...       ...         ...
# 89       types  0.001072       india
# 90     various  0.002488       india
# 91        work  0.000989       india
# 92     working  0.001352       india
# 93       years  0.001686       india
#
# [243 rows x 3 columns]

# %%
df_new.to_excel('/Users/Ketki/Documents/MS Theses/Reference Papers and Data/Outputs/freq_china.xlsx')

# %%
import matplotlib.pyplot as plt
import wordcloud

# %%
wc = wordcloud(words = df_new$word, freq = df_new$freq, max.words=250,random.order=FALSE,ordered.colors=TRUE,colors=brewer.pal(8,'Dark2')[factor(df_new$nationality)])
plt.imshow(wc, interpolation = 'bilinear')
plt.axis('off')
plt.show()
# Out:
#   File "<ipython-input-66-84387c626134>", line 1
#     wc = wordcloud(words = df_new$word, freq = df_new$freq, max.words=250,random.order=FALSE,ordered.colors=TRUE,colors=brewer.pal(8,'Dark2')[factor(df_new$nationality)])
#                                  ^
# SyntaxError: invalid syntax
